# %%
import os
print(os.getcwd())
try:
    os.chdir(r'F:\Dropbox\Work\Data\behavioral\attention\StatisticalRegularities\locations\Salience\Exp3\beh')
except:
    os.chdir('/Users/michlf/Dropbox/Work/Data/behavioral/attention/StatisticalRegularities/locations/Salience/Exp3/beh')
print(os.getcwd())
# Out:
# F:\Dropbox\Work\Data\behavioral\attention\StatisticalRegularities\locations\Salience\Exp3\beh
# F:\Dropbox\Work\Data\behavioral\attention\StatisticalRegularities\locations\Salience\Exp3\beh

# %%
import pandas as pd
fields = ['responseTime', 'subject_nr','cond_probLocation', 'correct', 'cond_disPresent',
          'cond_congruency', 'cond_disProbability','cond_salience','count_blockLoop', 'cond_tarLocation'] # leave None if all columns are needed
noTrials = 1920 # if the dataset has an additional row (e.g. when questions were stored), leave None else

# %%
data = []
for i in range(1,len([s for s in os.listdir(os.getcwd()) if 'subject-' in s]) + 1):
    d = pd.read_csv('subject-{0}.csv'.format(i), sep=',', usecols=fields, decimal=b'.')
    if noTrials and len(d) > noTrials:
        d = d[:noTrials]
    data.append(d)

data = pd.concat(data, join='inner', ignore_index=True) # 'inner' to only get shared columns
data.tail()
# Out:
#       cond_congruency cond_disPresent cond_disProbability cond_probLocation  \
# 28795     incongruent         present            lowProb3           lowProb
# 28796       congruent         present            lowProb6           lowProb
# 28797       congruent          absent            highProb          highProb
# 28798     incongruent          absent            lowProb2           lowProb
# 28799     incongruent          absent            lowProb6           lowProb
#
#       cond_salience cond_tarLocation  correct  count_blockLoop  responseTime  \
# 28795          high         highProb        1               12    529.876329
# 28796          high         highProb        1               12    625.673140
# 28797          high          lowProb        1               12    584.698001
# 28798          high          lowProb        1               12    598.605469
# 28799          high         highProb        0               12    840.042950
#
#        subject_nr
# 28795          15
# 28796          15
# 28797          15
# 28798          15
# 28799          15

# %%
import numpy as np
# Do some manual filters
data['RT constrained'] = np.where( (data['responseTime']<200) | (data['responseTime']>2000), 0, 1)
data.head()
# Out:
#   cond_congruency cond_disPresent cond_disProbability cond_probLocation  \
# 0     incongruent         present            highProb          highProb
# 1     incongruent         present            lowProb7           lowProb
# 2       congruent         present            highProb          highProb
# 3       congruent          absent            highProb          highProb
# 4     incongruent         present            highProb          highProb
#
#   cond_salience cond_tarLocation  correct  count_blockLoop  responseTime  \
# 0           low          lowProb        1                1    968.561721
# 1           low          lowProb        1                1    655.416886
# 2           low          lowProb        1                1    676.713878
# 3           low          lowProb        1                1    542.334847
# 4           low          lowProb        1                1    662.693238
#
#    subject_nr  RT constrained
# 0           1               1
# 1           1               1
# 2           1               1
# 3           1               1
# 4           1               1

# %%
# Save it
data.to_excel("allData.xlsx", index=False)

# %%
dataDis = pd.pivot_table(data[ ( data.cond_disPresent == "present") & (data.correct == 1) & (data['RT constrained'] == 1)],
                         values="responseTime", index="subject_nr", columns=["cond_salience", "cond_probLocation"])
dataDis
# Out:
# cond_salience            high                       low
# cond_probLocation    highProb      lowProb     highProb      lowProb
# subject_nr
# 1                  558.540442   603.504492   601.013835   620.514106
# 2                  776.798191   782.241101   702.131677   730.405066
# 3                  923.947636   925.178294  1013.651024  1022.284284
# 4                  757.761054   809.097802   687.897484   770.222737
# 5                  842.273785   843.667753   820.353162   873.249699
# 6                  564.402397   605.081066   563.297345   597.464032
# 7                  867.113363   893.682657  1028.273568  1045.895590
# 8                  837.998023   935.639925   684.083620   738.477523
# 9                  782.103227   800.272884   908.154900   906.286709
# 10                 995.304695  1058.411674   868.308957   939.703542
# 11                 680.994514   699.387831   751.134346   775.846991
# 12                 751.942170   799.700752   609.555872   660.737078
# 13                 744.486445   809.077106   860.587459   915.956013
# 14                 636.671060   693.879105   630.770873   689.519947
# 15                 594.999824   621.140870   665.770544   680.187283

# %%
dataDis = pd.melt( dataDis.reset_index(),id_vars="subject_nr", value_name="responseTime")
dataDis.head(10)
# Out:
#    subject_nr cond_salience cond_probLocation  responseTime
# 0           1          high          highProb    558.540442
# 1           2          high          highProb    776.798191
# 2           3          high          highProb    923.947636
# 3           4          high          highProb    757.761054
# 4           5          high          highProb    842.273785
# 5           6          high          highProb    564.402397
# 6           7          high          highProb    867.113363
# 7           8          high          highProb    837.998023
# 8           9          high          highProb    782.103227
# 9          10          high          highProb    995.304695

# %%
import seaborn as sns
ax = sns.catplot(x="cond_probLocation", y="responseTime", hue="cond_salience", kind="point",
            ci=None, units="responseTime", data=dataDis)

# %%
dataTar = pd.pivot_table(data[ ( data.cond_disPresent == "absent") & (data.correct == 1) & (data['RT constrained'] == 1)],
                         values="responseTime", index="subject_nr", columns=["cond_salience", "cond_tarLocation"])
dataTar.head()
# Out:
# cond_salience           high                     low
# cond_tarLocation    highProb     lowProb    highProb      lowProb
# subject_nr
# 1                 633.772193  559.840025  593.250875   582.284954
# 2                 842.276056  747.275511  683.952788   701.294255
# 3                 770.572820  862.240913  987.887878  1018.652127
# 4                 717.872432  718.652825  679.247129   683.161792
# 5                 853.272753  843.746982  851.352424   820.686926

# %%
dataTar = pd.melt( dataTar.reset_index(),id_vars="subject_nr", value_name="responseTime")

ax = sns.catplot(x="cond_tarLocation", y="responseTime", hue="cond_salience", kind="point",
            ci=None, units="responseTime", data=dataTar)
